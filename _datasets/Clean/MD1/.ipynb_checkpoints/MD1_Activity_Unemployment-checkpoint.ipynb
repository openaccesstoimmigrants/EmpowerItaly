nord-ovest","foreign",2021,13.2247126667,12.4710106667,13.6,14.408137,65.327416,72.853186,69.5,74.8935856667],[44,"Nord-ovest","foreign",2022,10.6729363333,10.163093,10.5,10.377461,66.026004,75.1318963333,70.7,76.266436],[45,"Nord-ovest","italian",2018,8.359876,3.4741703333,6.1,6.0883586667,55.1566996667,86.4393203333,70.0,75.2604966667],[46,"Nord-ovest","italian",2019,8.4793926667,2.9877563333,5.7,5.4687883333,55.9986083333,86.2566926667,70.3,74.9550113333],[47,"Nord-ovest","italian",2020,7.4081536667,3.1971976667,5.3,5.2682043333,53.6400383333,84.664571,68.4,73.171798],[48,"Nord-ovest","italian",2021,7.8058013333,3.1203913333,5.5,5.419123,54.156985,85.7423486667,69.0,73.8004693333],[49,"Nord-ovest","italian",2022,6.9459236667,2.522901,4.7,4.6533653333,54.7419213333,86.3619403333,69.9,74.8170903333]]}'''


# Parse the given JSON
parsed_json = json.loads(given_json)

# Initialize an empty list to store the transformed data
result = []

# Extract data from the parsed JSON, transform it, and map education levels
for key, value in parsed_json['Year'].items():
    result.append({
        'Territory':parsed_json['Territory'][key],
        'Citizenship':parsed_json['Citizenship'][key],
        'Year': value,
        'UnEmployment1': parsed_json['UNEMP_ED_1'][key],
        'UnEmployment3': parsed_json['UNEMP_ED_3'][key],
        'totalUnemployment': parsed_json['total'][key],
        'SecondarySchoo': parsed_json['UNEMP_ED_2'][key]
    })

# Convert the transformed data to JSON format
transformed_json = json.dumps(result, indent=2)
print(transformed_json)


# Save the new file

# Specify the folder path to save the JSON file
folder_path = "../_datasets/Clean/D7"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Define the filename for the JSON file
filename = "unemployment_rate.json"

# Generate the file path
file_path = os.path.join(folder_path, filename)

# Save the resident Italian population JSON to the file
with open(file_path, "w") as file:
    file.write(transformed_json)

print(f"JSON data saved to: {file_path}")
# Out:
# [
#   {
#     "Territory": "Centro (I)",
#     "Citizenship": "foreign",
#     "Year": "2018",
#     "PrimarySchool": 15.1556266667,
#     "TertiarySchool": 10.8040806667,
#     "total": 14.4532273333,
#     "SecondarySchool": 14.83671
#   },
#   {
#     "Territory": "Centro (I)",
#     "Citizenship": "foreign",
#     "Year": "2019",
#     "PrimarySchool": 13.5684366667,
#     "TertiarySchool": 11.434287,
#     "total": 14.8460583333,
#     "SecondarySchool": 17.514611
#   },
#   {
#     "Territory": "Centro (I)",
#     "Citizenship": "foreign",
#     "Year": "2020",
#     "PrimarySchool": 13.1537456667,
#     "TertiarySchool": 8.6245346667,
#     "total": 12.7785246667,
#     "SecondarySchool": 13.5420316667
#   },
#   {
#     "Territory": "Centro (I)",
#     "Citizenship": "foreign",
#     "Year": "2021",
#     "PrimarySchool": 13.2418526667,
#     "TertiarySchool": 18.1025996667,
#     "total": 15.1945003333,
#     "SecondarySchool": 16.5862913333
#   },
#   {
# ...
