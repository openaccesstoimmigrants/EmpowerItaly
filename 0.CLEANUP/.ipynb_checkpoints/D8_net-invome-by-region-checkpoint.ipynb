# %% [markdown]
# # D8
# ## Net income
# ### [See on IstatData](https://esploradati.istat.it/databrowser/#/en/dw/categories/IT1,HOU,1.0/HOU_INCOME/DCCV_REDNETFAMFONTERED/IT1,32_292_DF_DCCV_REDNETFAMFONTERED_9,1.0)

# %%
#!pip install pandas requests requests_cache xmltodict

# %%
import pandas as pd
import json
import requests
import xmltodict
from datetime import datetime
import os

# %%
# 1 - Explore Data Structure

response = requests.get('https://esploradati.istat.it/SDMXWS/rest/datastructure/IT1/DCCV_REDNETFAMFONTERED/')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Uncomment the following line to see the resulting JSON string
# print(json_string_data)
type(json_string_data)
# Out:
# 200
# str

# %% [markdown]
# "FREQ" value="A"
# "REF_AREA" value="IT"
# "DATA_TYPE" value="REDD_MEDIO_FAM"
# "MEASURE" value="9"
# "IMPUTED_RENTS" value="1"
# "FAM_MAIN_INCOME_SOURCE" value="9"
# "NUMBER_HOUSEHOLD_COMP" value="2"
# "HOUSEHOLD_TYPOLOGY" value="99"
# "NUMB_OF_CHILDREN" value="9"
# "NUMB_OF_ELDERLY" value="9"
# "SEX_MAIN_PERCEPTOR" value="9"
# "AGE_MAIN_EARNIER" value="TOTAL"
# "EDU_LEV_MAIN_EARN" value="99"
# "LABPROF_STATUS_C_MAIN_EARNER" value="99"

# %%
# 2 - Explore the meaning of the dimensions of the dataset

response = requests.get('https://esploradati.istat.it/SDMXWS/rest/codelist/IT1/CL_TIPOLOGIA_FAMILIARE1')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Uncomment the following line to see the resulting JSON string
# print(json_string_data)
# Out:
# 200

# %%
# 3 -  Explore values in Dimensions

response = requests.get('https://esploradati.istat.it/SDMXWS/rest/availableconstraint/32_292_DF_DCCV_REDNETFAMFONTERED_1')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Uncomment the following line to see the resulting JSON string
# print(json_string_data)
# Out:
# 200

# %%
# 4 -  Final query with filters

response = requests.get('https://esploradati.istat.it/SDMXWS/rest/data/32_292_DF_DCCV_REDNETFAMFONTERED_1/A.IT+ITC+ITD+ITE+ITF+ITG.REDD_MEDIO_FAM.9.1.9.7.......')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Uncomment the following line to see the resulting JSON string
print(json_string_data)
# Out:
# 200
# {
#       "message:GenericData": {
#             "@xmlns:footer": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message/footer",
#             "@xmlns:generic": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/data/generic",
#             "@xmlns:message": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message",
#             "@xmlns:common": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common",
#             "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#             "@xmlns:xml": "http://www.w3.org/XML/1998/namespace",
#             "message:Header": {
#                   "message:ID": "IREFc4abcc4e674b4519b24faed161dbeeae",
#                   "message:Test": "true",
#                   "message:Prepared": "2023-10-15T12:34:51",
#                   "message:Sender": {
#                         "@id": "SOME_NSI"
#                   },
#                   "message:Structure": {
#                         "@structureID": "IT1_DCCV_REDNETFAMFONTERED_1_1",
#                         "@dimensionAtObservation": "TIME_PERIOD",
#                         "common:Structure": {
#                               "Ref": {
#                                     "@agencyID": "IT1",
#                                     "@id": "DCCV_REDNETFAMFONTERED",
#                                     "@version": "1.1"
#                               }
#                         }
#                   },
#                   "message:DataSetAction": "Information"
#             },
#             "message:DataSet": {
#                   "@action": "Information",
#                   "@structureRef": "IT1_DCCV_REDNETFAMFONTERED_1_1",
#                   "generic:Series": [
#                         {
#                               "generic:SeriesKey": {
#                                     "generic:Value": [
#                                           {
#                                                 "@id": "FREQ",
#                                                 "@value": "A"
#                                           },
#                                           {
#                                                 "@id": "CLASSE_ETA_PPERC",
#                                                 "@value": "TOTAL"
#                                           },
#                                           {
#                                                 "@id": "ITTER107",
#                                                 "@value": "IT"
#                                           },
#                                           {
#                                                 "@id": "MISURA1",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "COND_PROF_PREV_PPERC",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "NUM_COMPONENTI",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "PRES_AFF_IMP",
#                                                 "@value": "2"
#                                           },
#                                           {
#                                                 "@id": "FONTE_REDPRINC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "SESSO_PPERC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPOLOGIA_FAM",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "FAM_ANZIANI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "FAM_MINORI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPO_DATO",
#                                                 "@value": "REDD_MEDIANO_FAM"
#                                           },
#                                           {
#                                                 "@id": "TITOLO_STUDIO_PPERC",
#                                                 "@value": "99"
#                                           }
#                                     ]
#                               },
#                               "generic:Obs": [
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2003"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "21635"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2004"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22338"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2005"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22731"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2006"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23494"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2007"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24269"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2008"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24435"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2009"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25019"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2010"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24606"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2011"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24811"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2012"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24171"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2013"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24310"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2014"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24190"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2015"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24522"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2016"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25091"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2017"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25426"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2018"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25716"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2019"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27102"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2020"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26597"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2021"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26979"
#                                           }
#                                     }
#                               ]
#                         },
#                         {
#                               "generic:SeriesKey": {
#                                     "generic:Value": [
#                                           {
#                                                 "@id": "FREQ",
#                                                 "@value": "A"
#                                           },
#                                           {
#                                                 "@id": "CLASSE_ETA_PPERC",
#                                                 "@value": "TOTAL"
#                                           },
#                                           {
#                                                 "@id": "ITTER107",
#                                                 "@value": "IT"
#                                           },
#                                           {
#                                                 "@id": "MISURA1",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "COND_PROF_PREV_PPERC",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "NUM_COMPONENTI",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "PRES_AFF_IMP",
#                                                 "@value": "2"
#                                           },
#                                           {
#                                                 "@id": "FONTE_REDPRINC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "SESSO_PPERC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPOLOGIA_FAM",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "FAM_ANZIANI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "FAM_MINORI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPO_DATO",
#                                                 "@value": "REDD_MEDIO_FAM"
#                                           },
#                                           {
#                                                 "@id": "TITOLO_STUDIO_PPERC",
#                                                 "@value": "99"
#                                           }
#                                     ]
#                               },
#                               "generic:Obs": [
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2003"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26919"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2004"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27857"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2005"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "28020"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2006"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29144"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2007"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29663"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2008"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30090"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2009"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30502"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2010"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30220"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2011"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30236"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2012"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29579"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2013"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29473"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2014"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29472"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2015"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29988"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2016"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30595"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2017"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "31393"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2018"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "31641"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2019"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "33106"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2020"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "32812"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2021"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "33798"
#                                           }
#                                     }
#                               ]
#                         },
#                         {
#                               "generic:SeriesKey": {
#                                     "generic:Value": [
#                                           {
#                                                 "@id": "FREQ",
#                                                 "@value": "A"
#                                           },
#                                           {
#                                                 "@id": "CLASSE_ETA_PPERC",
#                                                 "@value": "TOTAL"
#                                           },
#                                           {
#                                                 "@id": "ITTER107",
#                                                 "@value": "ITC"
#                                           },
#                                           {
#                                                 "@id": "MISURA1",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "COND_PROF_PREV_PPERC",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "NUM_COMPONENTI",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "PRES_AFF_IMP",
#                                                 "@value": "2"
#                                           },
#                                           {
#                                                 "@id": "FONTE_REDPRINC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "SESSO_PPERC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPOLOGIA_FAM",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "FAM_ANZIANI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "FAM_MINORI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPO_DATO",
#                                                 "@value": "REDD_MEDIANO_FAM"
#                                           },
#                                           {
#                                                 "@id": "TITOLO_STUDIO_PPERC",
#                                                 "@value": "99"
#                                           }
#                                     ]
#                               },
#                               "generic:Obs": [
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2003"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23595"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2004"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24561"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2005"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24702"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2006"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25219"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2007"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26057"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2008"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26728"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2009"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27481"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2010"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27576"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2011"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27615"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2012"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26969"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2013"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26815"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2014"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26987"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2015"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26786"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2016"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26954"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2017"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27713"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2018"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "27959"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2019"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29965"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2020"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29421"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2021"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "29075"
#                                           }
#                                     }
#                               ]
#                         },
#                         {
#                               "generic:SeriesKey": {
#                                     "generic:Value": [
#                                           {
#                                                 "@id": "FREQ",
#                                                 "@value": "A"
#                                           },
#                                           {
#                                                 "@id": "CLASSE_ETA_PPERC",
#                                                 "@value": "TOTAL"
#                                           },
#                                           {
#                                                 "@id": "ITTER107",
#                                                 "@value": "ITC"
#                                           },
#                                           {
#                                                 "@id": "MISURA1",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "COND_PROF_PREV_PPERC",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "NUM_COMPONENTI",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "PRES_AFF_IMP",
#                                                 "@value": "2"
#                                           },
#                                           {
#                                                 "@id": "FONTE_REDPRINC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "SESSO_PPERC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPOLOGIA_FAM",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "FAM_ANZIANI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "FAM_MINORI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPO_DATO",
#                                                 "@value": "REDD_MEDIO_FAM"
#                                           },
#                                           {
#                                                 "@id": "TITOLO_STUDIO_PPERC",
#                                                 "@value": "99"
#                                           }
#                                     ]
#                               },
#                               "generic:Obs": [
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2003"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "28952"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2004"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30416"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2005"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "30147"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2006"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "31171"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2007"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "31594"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2008"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "32337"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2009"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "33135"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2010"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "33392"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
# ...
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2016"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "19730"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2017"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "20138"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2018"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "20568"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2019"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "21083"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2020"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "21997"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2021"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22757"
#                                           }
#                                     }
#                               ]
#                         },
#                         {
#                               "generic:SeriesKey": {
#                                     "generic:Value": [
#                                           {
#                                                 "@id": "FREQ",
#                                                 "@value": "A"
#                                           },
#                                           {
#                                                 "@id": "CLASSE_ETA_PPERC",
#                                                 "@value": "TOTAL"
#                                           },
#                                           {
#                                                 "@id": "ITTER107",
#                                                 "@value": "ITG"
#                                           },
#                                           {
#                                                 "@id": "MISURA1",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "COND_PROF_PREV_PPERC",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "NUM_COMPONENTI",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "PRES_AFF_IMP",
#                                                 "@value": "2"
#                                           },
#                                           {
#                                                 "@id": "FONTE_REDPRINC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "SESSO_PPERC",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPOLOGIA_FAM",
#                                                 "@value": "99"
#                                           },
#                                           {
#                                                 "@id": "FAM_ANZIANI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "FAM_MINORI",
#                                                 "@value": "9"
#                                           },
#                                           {
#                                                 "@id": "TIPO_DATO",
#                                                 "@value": "REDD_MEDIO_FAM"
#                                           },
#                                           {
#                                                 "@id": "TITOLO_STUDIO_PPERC",
#                                                 "@value": "99"
#                                           }
#                                     ]
#                               },
#                               "generic:Obs": [
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2003"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "21742"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2004"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22657"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2005"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22854"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2006"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23295"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2007"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24065"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2008"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23981"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2009"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24447"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2010"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22693"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2011"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23167"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2012"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22787"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2013"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22893"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2014"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "22564"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2015"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23014"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2016"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "23153"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2017"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24065"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2018"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "24934"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2019"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "25851"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2020"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26780"
#                                           }
#                                     },
#                                     {
#                                           "generic:ObsDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@value": "2021"
#                                           },
#                                           "generic:ObsValue": {
#                                                 "@value": "26409"
#                                           }
#                                     }
#                               ]
#                         }
#                   ]
#             }
#       }
# }

# %% [markdown]
# Now we crate a well formed JSON sting from the response.
#
# The code snippet performs the following tasks:
#
# 1. It takes a JSON string called `json_string_data` and creates a nested dictionary, `nested_dict`, using the `json.loads()` function. This step is essential to process and extract information from the JSON data.
#
# 2. It defines a translation dictionary, `sex_translation`, which maps numeric codes to corresponding gender labels ('1' to 'Male' and '2' to 'Female'). This dictionary will be used to translate the sex values later.
#
# 3. It initializes an empty list, `result`, which will store the extracted information from the nested dictionary.
#
# 4. It iterates over the series data in the nested dictionary. Each series represents a set of observations for a specific combination of variables.
#
# 5. Within each series, it retrieves the territory and sex values by searching for specific keys ('ITTER107' and 'SESSO') in the series key. If found, it assigns the corresponding values to the `territory` and `sex` variables, respectively. The sex value is translated using the `sex_translation` dictionary.
#
# 6. It retrieves the observation values (`obs_values`) for each series and iterates over them. Each observation contains information about the year, age, and quantity.
#
# 7. It creates an entry dictionary that contains the extracted information, including the territory, year, sex, age, and quantity.
#
# 8. The entry dictionary is appended to the `result` list.
#
# 9. Finally, the `result` list is converted to a JSON string, `immigrants_demographic`, using `json.dumps()`. The type of the `immigrants_demographic` variable is printed to verify that it is a string.
#
# In summary, sintethis code processes the nested dictionary, extracts specific information, translates values, and organizes the extracted data into a clean JSON format suitable for visualization or further analysis.

# %%
# Convert the JSON string to a Python dictionary
nested_dict = json.loads(json_string_data)

# Accessing values in the nested dictionary
header_id = nested_dict['message:GenericData']['message:Header']['message:ID']
dataset_action = nested_dict['message:GenericData']['message:DataSet']['@action']

# Extract observation values for different regions
regions_data = {}
for series in nested_dict['message:GenericData']['message:DataSet']['generic:Series']:
    region_id = None
    obs_values = []
    for item in series['generic:SeriesKey']['generic:Value']:
        if item['@id'] == 'ITTER107':
            region_id = item['@value']
    for obs in series['generic:Obs']:
        obs_values.append({
            'TIME_PERIOD': obs['generic:ObsDimension']['@value'],
            'ObsValue': obs['generic:ObsValue']['@value']
        })
    regions_data[region_id] = obs_values

# Printing the values
print("Header ID:", header_id)
print("Dataset Action:", dataset_action)
print("Series Values:", series_values)

# Printing the values for each region
for region, data in regions_data.items():
    print(f"Region: {region}")
    for entry in data:
        print(f"TIME_PERIOD: {entry['TIME_PERIOD']} - ObsValue: {entry['ObsValue']}")


print(type(nested_dict))
# Out:
# Header ID: IREFc4abcc4e674b4519b24faed161dbeeae
# Dataset Action: Information
# Series Values: [{'FREQ': 'A'}, {'CLASSE_ETA_PPERC': 'TOTAL'}, {'ITTER107': 'IT'}, {'MISURA1': '9'}, {'COND_PROF_PREV_PPERC': '99'}, {'NUM_COMPONENTI': '99'}, {'PRES_AFF_IMP': '2'}, {'FONTE_REDPRINC': '9'}, {'SESSO_PPERC': '9'}, {'TIPOLOGIA_FAM': '99'}, {'FAM_ANZIANI': '9'}, {'FAM_MINORI': '9'}, {'TIPO_DATO': 'REDD_MEDIANO_FAM'}, {'TITOLO_STUDIO_PPERC': '99'}]
# Region: IT
# TIME_PERIOD: 2003 - ObsValue: 26919
# TIME_PERIOD: 2004 - ObsValue: 27857
# TIME_PERIOD: 2005 - ObsValue: 28020
# TIME_PERIOD: 2006 - ObsValue: 29144
# TIME_PERIOD: 2007 - ObsValue: 29663
# TIME_PERIOD: 2008 - ObsValue: 30090
# TIME_PERIOD: 2009 - ObsValue: 30502
# TIME_PERIOD: 2010 - ObsValue: 30220
# TIME_PERIOD: 2011 - ObsValue: 30236
# TIME_PERIOD: 2012 - ObsValue: 29579
# TIME_PERIOD: 2013 - ObsValue: 29473
# TIME_PERIOD: 2014 - ObsValue: 29472
# TIME_PERIOD: 2015 - ObsValue: 29988
# TIME_PERIOD: 2016 - ObsValue: 30595
# TIME_PERIOD: 2017 - ObsValue: 31393
# TIME_PERIOD: 2018 - ObsValue: 31641
# TIME_PERIOD: 2019 - ObsValue: 33106
# TIME_PERIOD: 2020 - ObsValue: 32812
# TIME_PERIOD: 2021 - ObsValue: 33798
# Region: ITC
# TIME_PERIOD: 2003 - ObsValue: 28952
# TIME_PERIOD: 2004 - ObsValue: 30416
# TIME_PERIOD: 2005 - ObsValue: 30147
# TIME_PERIOD: 2006 - ObsValue: 31171
# TIME_PERIOD: 2007 - ObsValue: 31594
# TIME_PERIOD: 2008 - ObsValue: 32337
# TIME_PERIOD: 2009 - ObsValue: 33135
# TIME_PERIOD: 2010 - ObsValue: 33392
# TIME_PERIOD: 2011 - ObsValue: 33317
# TIME_PERIOD: 2012 - ObsValue: 32901
# TIME_PERIOD: 2013 - ObsValue: 32390
# TIME_PERIOD: 2014 - ObsValue: 32888
# TIME_PERIOD: 2015 - ObsValue: 32680
# TIME_PERIOD: 2016 - ObsValue: 33268
# TIME_PERIOD: 2017 - ObsValue: 34211
# TIME_PERIOD: 2018 - ObsValue: 34642
# TIME_PERIOD: 2019 - ObsValue: 36224
# TIME_PERIOD: 2020 - ObsValue: 36018
# TIME_PERIOD: 2021 - ObsValue: 37647
# Region: ITD
# TIME_PERIOD: 2003 - ObsValue: 29386
# TIME_PERIOD: 2004 - ObsValue: 30132
# TIME_PERIOD: 2005 - ObsValue: 30529
# TIME_PERIOD: 2006 - ObsValue: 31942
# TIME_PERIOD: 2007 - ObsValue: 32427
# TIME_PERIOD: 2008 - ObsValue: 33111
# TIME_PERIOD: 2009 - ObsValue: 33007
# TIME_PERIOD: 2010 - ObsValue: 33548
# TIME_PERIOD: 2011 - ObsValue: 33120
# TIME_PERIOD: 2012 - ObsValue: 32547
# TIME_PERIOD: 2013 - ObsValue: 32746
# TIME_PERIOD: 2014 - ObsValue: 32783
# TIME_PERIOD: 2015 - ObsValue: 33852
# TIME_PERIOD: 2016 - ObsValue: 34678
# TIME_PERIOD: 2017 - ObsValue: 35386
# TIME_PERIOD: 2018 - ObsValue: 35165
# TIME_PERIOD: 2019 - ObsValue: 37046
# TIME_PERIOD: 2020 - ObsValue: 36418
# TIME_PERIOD: 2021 - ObsValue: 38340
# Region: ITE
# TIME_PERIOD: 2003 - ObsValue: 28840
# TIME_PERIOD: 2004 - ObsValue: 29729
# TIME_PERIOD: 2005 - ObsValue: 30003
# TIME_PERIOD: 2006 - ObsValue: 31509
# TIME_PERIOD: 2007 - ObsValue: 31936
# TIME_PERIOD: 2008 - ObsValue: 32132
# TIME_PERIOD: 2009 - ObsValue: 32543
# TIME_PERIOD: 2010 - ObsValue: 31950
# TIME_PERIOD: 2011 - ObsValue: 31910
# TIME_PERIOD: 2012 - ObsValue: 30818
# TIME_PERIOD: 2013 - ObsValue: 30750
# TIME_PERIOD: 2014 - ObsValue: 30376
# TIME_PERIOD: 2015 - ObsValue: 31147
# TIME_PERIOD: 2016 - ObsValue: 32006
# TIME_PERIOD: 2017 - ObsValue: 32945
# TIME_PERIOD: 2018 - ObsValue: 32988
# TIME_PERIOD: 2019 - ObsValue: 34588
# TIME_PERIOD: 2020 - ObsValue: 33837
# TIME_PERIOD: 2021 - ObsValue: 34555
# Region: ITF
# TIME_PERIOD: 2003 - ObsValue: 22834
# TIME_PERIOD: 2004 - ObsValue: 23308
# TIME_PERIOD: 2005 - ObsValue: 23703
# TIME_PERIOD: 2006 - ObsValue: 24683
# TIME_PERIOD: 2007 - ObsValue: 25281
# TIME_PERIOD: 2008 - ObsValue: 25508
# TIME_PERIOD: 2009 - ObsValue: 25862
# TIME_PERIOD: 2010 - ObsValue: 25123
# TIME_PERIOD: 2011 - ObsValue: 25451
# TIME_PERIOD: 2012 - ObsValue: 24639
# TIME_PERIOD: 2013 - ObsValue: 24632
# TIME_PERIOD: 2014 - ObsValue: 24450
# TIME_PERIOD: 2015 - ObsValue: 25206
# TIME_PERIOD: 2016 - ObsValue: 25615
# TIME_PERIOD: 2017 - ObsValue: 26089
# TIME_PERIOD: 2018 - ObsValue: 26393
# TIME_PERIOD: 2019 - ObsValue: 27470
# TIME_PERIOD: 2020 - ObsValue: 27189
# TIME_PERIOD: 2021 - ObsValue: 27467
# Region: ITG
# TIME_PERIOD: 2003 - ObsValue: 21742
# TIME_PERIOD: 2004 - ObsValue: 22657
# TIME_PERIOD: 2005 - ObsValue: 22854
# TIME_PERIOD: 2006 - ObsValue: 23295
# TIME_PERIOD: 2007 - ObsValue: 24065
# TIME_PERIOD: 2008 - ObsValue: 23981
# TIME_PERIOD: 2009 - ObsValue: 24447
# TIME_PERIOD: 2010 - ObsValue: 22693
# TIME_PERIOD: 2011 - ObsValue: 23167
# TIME_PERIOD: 2012 - ObsValue: 22787
# TIME_PERIOD: 2013 - ObsValue: 22893
# TIME_PERIOD: 2014 - ObsValue: 22564
# TIME_PERIOD: 2015 - ObsValue: 23014
# TIME_PERIOD: 2016 - ObsValue: 23153
# TIME_PERIOD: 2017 - ObsValue: 24065
# TIME_PERIOD: 2018 - ObsValue: 24934
# TIME_PERIOD: 2019 - ObsValue: 25851
# TIME_PERIOD: 2020 - ObsValue: 26780
# TIME_PERIOD: 2021 - ObsValue: 26409
# <class 'dict'>

# %% [markdown]
# The next code snippet performs the following tasks:
#
# 1. It converts the `immigrants_demographic` string, which contains a JSON representation, into a JSON object using `json.loads()`. This step allows easier manipulation and access to the data.
#
# 2. It specifies the folder path where the resulting JSON file will be saved. In this case, the folder path is "../_datasets/Clean".
#
# 3. It creates the specified folder if it does not already exist using `os.makedirs()`. This ensures that the folder is available to store the JSON file.
#
# 4. It defines the filename for the JSON file as "immigrants_demographic.json".
#
# 5. It generates the complete file path by joining the folder path and filename using `os.path.join()`.
#
# 6. It saves the `immigrants_demographic_json` JSON object to a file specified by the file path. This is achieved using `json.dump()` with the file opened in write mode ("w").
#
# 7. The JSON data is formatted with an indent of 4 spaces to improve readability within the file.
#
# 8. Finally, it prints a message confirming the successful saving of the JSON data, along with the file path where it was saved.
#
# So basically this code snippet takes a JSON object, saves it as a JSON file in a specified directory, and provides feedback on the successful saving of the file.

# %%
# Save the new file

# Specify the folder path to save the JSON file
folder_path = "../_datasets/Clean/D4/"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Define the filename for the JSON file
filename = "net_income_by_regions_data.json"

# Generate the file path
file_path = os.path.join(folder_path, filename)

# Save the regions_data dictionary to a JSON file
with open(file_path, "w") as file:
    json.dump(regions_data, file, indent=4)

print(f"JSON data saved to: {file_path}")
# Out:
# JSON data saved to: ../_datasets/Clean/net_income_by_regions_data.json
