# %% [markdown]
# # D4
# ## ISTAT SDMX - Net income on 1st January
#
# [See on IstatData]
# // NOT PRESENT(https://esploradati.istat.it/databrowser/#/it/dw/categories/IT1,POP,1.0/POP_FOREIGNIM/DCIS_POPSTRRES1/IT1,29_7_DF_DCIS_POPSTRRES1_1,1.0)

# %%
#!pip install pandasdmx requests requests_cache xmltodict

# %%
import pandas as pd
import pandasdmx as sdmx
import json
import requests
# from pandasdmx import Request
import xmltodict
from datetime import datetime
import os

# %%
# 1 -  EXPLORE DATASTRUCTURE
response = requests.get('http://sdmx.istat.it/SDMXWS/rest/datastructure/IT1/DCCV_REDNETFAMFONTERED/')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

print(json_string_data)
type(json_string_data)
# Out:
# 200
# {
#       "message:Structure": {
#             "@xmlns:message": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message",
#             "@xmlns:structure": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/structure",
#             "@xmlns:common": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common",
#             "message:Header": {
#                   "message:ID": "IDREF37",
#                   "message:Test": "false",
#                   "message:Prepared": "2023-10-14T17:14:53.4483124+02:00",
#                   "message:Sender": {
#                         "@id": "Unknown"
#                   },
#                   "message:Receiver": {
#                         "@id": "Unknown"
#                   }
#             },
#             "message:Structures": {
#                   "structure:DataStructures": {
#                         "structure:DataStructure": {
#                               "@id": "DCCV_REDNETFAMFONTERED",
#                               "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=IT1:DCCV_REDNETFAMFONTERED(1.3)",
#                               "@agencyID": "IT1",
#                               "@version": "1.3",
#                               "@validFrom": "2019-04-15T00:00:00",
#                               "@validTo": "2099-12-31T00:00:00",
#                               "@isFinal": "true",
#                               "common:Name": [
#                                     {
#                                           "@xml:lang": "it",
#                                           "#text": "Reddito netto"
#                                     },
#                                     {
#                                           "@xml:lang": "en",
#                                           "#text": "Net income"
#                                     }
#                               ],
#                               "structure:DataStructureComponents": {
#                                     "structure:DimensionList": {
#                                           "@id": "DimensionDescriptor",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DimensionDescriptor=IT1:DCCV_REDNETFAMFONTERED(1.3).DimensionDescriptor",
#                                           "structure:Dimension": [
#                                                 {
#                                                       "@id": "FREQ",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).FREQ",
#                                                       "@position": "1",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "FREQ",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_FREQ",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "COND_PROF_PREV_PPERC",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).COND_PROF_PREV_PPERC",
#                                                       "@position": "2",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "COND_PROF_PREV_PPERC",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_CONDIZIONE_DICH2",
#                                                                         "@version": "1.3",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "CLASSE_ETA_PPERC",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).CLASSE_ETA_PPERC",
#                                                       "@position": "3",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "CLASSE_ETA_PPERC",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_ETA1",
#                                                                         "@version": "2.3",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "ITTER107",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).ITTER107",
#                                                       "@position": "4",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "ITTER107",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_ITTER107",
#                                                                         "@version": "4.6",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "MISURA1",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).MISURA1",
#                                                       "@position": "5",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "MISURA1",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_MISURA1",
#                                                                         "@version": "3.5",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "NUM_COMPONENTI",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).NUM_COMPONENTI",
#                                                       "@position": "6",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "NUM_COMPONENTI",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_NUMERO_COMPONENTI",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "PRES_AFF_IMP",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).PRES_AFF_IMP",
#                                                       "@position": "7",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "PRES_AFF_IMP",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_PRESAFFITTI",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "FONTE_REDPRINC",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).FONTE_REDPRINC",
#                                                       "@position": "8",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "FONTE_REDPRINC",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_REDPRINC",
#                                                                         "@version": "1.1",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "SESSO_PPERC",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).SESSO_PPERC",
#                                                       "@position": "9",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "SESSO_PPERC",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_SEXISTAT1",
#                                                                         "@version": "1.8",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "TIPOLOGIA_FAM",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).TIPOLOGIA_FAM",
#                                                       "@position": "10",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "TIPOLOGIA_FAM",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_TIPOLOGIA_FAMILIARE1",
#                                                                         "@version": "1.1",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "FAM_ANZIANI",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).FAM_ANZIANI",
#                                                       "@position": "11",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "FAM_ANZIANI",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_TIPOLOGIA_FAM_ANZIANI",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "FAM_MINORI",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).FAM_MINORI",
#                                                       "@position": "12",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "FAM_MINORI",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_TIPOLOGIA_FAM_MINORI",
#                                                                         "@version": "1.1",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "TIPO_DATO",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).TIPO_DATO",
#                                                       "@position": "13",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "TIPO_DATO",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_TIPO_DATO8",
#                                                                         "@version": "1.5",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "TITOLO_STUDIO_PPERC",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.Dimension=IT1:DCCV_REDNETFAMFONTERED(1.3).TITOLO_STUDIO_PPERC",
#                                                       "@position": "14",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "TITOLO_STUDIO_PPERC",
#                                                                   "@maintainableParentID": "VARIAB_ALL",
#                                                                   "@maintainableParentVersion": "18.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_TITOLO_STUDIO",
#                                                                         "@version": "2.8",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       }
#                                                 }
#                                           ],
#                                           "structure:TimeDimension": {
#                                                 "@id": "TIME_PERIOD",
#                                                 "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.TimeDimension=IT1:DCCV_REDNETFAMFONTERED(1.3).TIME_PERIOD",
#                                                 "@position": "15",
#                                                 "structure:ConceptIdentity": {
#                                                       "Ref": {
#                                                             "@id": "SELECT_TIME",
#                                                             "@maintainableParentID": "CROSS_DOMAIN",
#                                                             "@maintainableParentVersion": "4.7",
#                                                             "@agencyID": "IT1",
#                                                             "@package": "conceptscheme",
#                                                             "@class": "Concept"
#                                                       }
#                                                 },
#                                                 "structure:LocalRepresentation": {
#                                                       "structure:TextFormat": {
#                                                             "@textType": "ObservationalTimePeriod"
#                                                       }
#                                                 }
#                                           }
#                                     },
#                                     "structure:Group": {
#                                           "@id": "X_MEASURE",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.GroupDimensionDescriptor=IT1:DCCV_REDNETFAMFONTERED(1.3).X_MEASURE",
#                                           "structure:GroupDimension": {
#                                                 "structure:DimensionReference": {
#                                                       "Ref": {
#                                                             "@id": "TIPO_DATO"
#                                                       }
#                                                 }
#                                           }
#                                     },
#                                     "structure:AttributeList": {
#                                           "@id": "AttributeDescriptor",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.AttributeDescriptor=IT1:DCCV_REDNETFAMFONTERED(1.3).AttributeDescriptor",
#                                           "structure:Attribute": [
#                                                 {
#                                                       "@id": "BREAK",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).BREAK",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "BREAK",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:TextFormat": {
#                                                                   "@textType": "String"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:PrimaryMeasure": {
#                                                                   "Ref": {
#                                                                         "@id": "OBS_VALUE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "CONF_STATUS",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).CONF_STATUS",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "CONF_STATUS",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_OBS_CONF",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             },
#                                                             "structure:EnumerationFormat": {
#                                                                   "@textType": "String"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:PrimaryMeasure": {
#                                                                   "Ref": {
#                                                                         "@id": "OBS_VALUE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "OBS_PRE_BREAK",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).OBS_PRE_BREAK",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "OBS_PRE_BREAK",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:TextFormat": {
#                                                                   "@textType": "String"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:PrimaryMeasure": {
#                                                                   "Ref": {
#                                                                         "@id": "OBS_VALUE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "OBS_STATUS",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).OBS_STATUS",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "OBS_STATUS",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_FLAG",
#                                                                         "@version": "1.6",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             },
#                                                             "structure:EnumerationFormat": {
#                                                                   "@textType": "String"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:PrimaryMeasure": {
#                                                                   "Ref": {
#                                                                         "@id": "OBS_VALUE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "BASE_PER",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).BASE_PER",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "BASE_PER",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_BASE_YEAR",
#                                                                         "@version": "1.3",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:Group": {
#                                                                   "Ref": {
#                                                                         "@id": "X_MEASURE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "UNIT_MEAS",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).UNIT_MEAS",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "UNIT_MEAS",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_UNIT_MEASURE",
#                                                                         "@version": "1.6",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:Group": {
#                                                                   "Ref": {
#                                                                         "@id": "X_MEASURE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "UNIT_MULT",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).UNIT_MULT",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "UNIT_MULT",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:LocalRepresentation": {
#                                                             "structure:Enumeration": {
#                                                                   "Ref": {
#                                                                         "@id": "CL_UNIT_MULT",
#                                                                         "@version": "1.0",
#                                                                         "@agencyID": "IT1",
#                                                                         "@package": "codelist",
#                                                                         "@class": "Codelist"
#                                                                   }
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:Group": {
#                                                                   "Ref": {
#                                                                         "@id": "X_MEASURE"
#                                                                   }
#                                                             }
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "METADATA_EN",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).METADATA_EN",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "METADATA_EN",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:None": null
#                                                       }
#                                                 },
#                                                 {
#                                                       "@id": "METADATA_IT",
#                                                       "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.DataAttribute=IT1:DCCV_REDNETFAMFONTERED(1.3).METADATA_IT",
#                                                       "@assignmentStatus": "Conditional",
#                                                       "structure:ConceptIdentity": {
#                                                             "Ref": {
#                                                                   "@id": "METADATA_IT",
#                                                                   "@maintainableParentID": "CROSS_DOMAIN",
#                                                                   "@maintainableParentVersion": "4.7",
#                                                                   "@agencyID": "IT1",
#                                                                   "@package": "conceptscheme",
#                                                                   "@class": "Concept"
#                                                             }
#                                                       },
#                                                       "structure:AttributeRelationship": {
#                                                             "structure:None": null
#                                                       }
#                                                 }
#                                           ]
#                                     },
#                                     "structure:MeasureList": {
#                                           "@id": "MeasureDescriptor",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.MeasureDescriptor=IT1:DCCV_REDNETFAMFONTERED(1.3).MeasureDescriptor",
#                                           "structure:PrimaryMeasure": {
#                                                 "@id": "OBS_VALUE",
#                                                 "@urn": "urn:sdmx:org.sdmx.infomodel.datastructure.PrimaryMeasure=IT1:DCCV_REDNETFAMFONTERED(1.3).OBS_VALUE",
#                                                 "structure:ConceptIdentity": {
#                                                       "Ref": {
#                                                             "@id": "OBS_VALUE",
#                                                             "@maintainableParentID": "CROSS_DOMAIN",
#                                                             "@maintainableParentVersion": "4.7",
#                                                             "@agencyID": "IT1",
#                                                             "@package": "conceptscheme",
#                                                             "@class": "Concept"
#                                                       }
#                                                 },
#                                                 "structure:LocalRepresentation": {
#                                                       "structure:TextFormat": {
#                                                             "@textType": "Double"
#                                                       }
#                                                 }
#                                           }
#                                     }
#                               }
#                         }
#                   }
#             }
#       }
# }
# str

# %% [markdown]
# By querying the API, we will obtain an XML output that includes the structure:DimensionList tag, which contains the list of dimensions, i.e., the data schema of the dataset. In our case, the dimensions are as follows: `FREQ`, `ITTER107`, `COND_PROF_PREV_PPERC`, `SESSO`, `NUM_COMPONENTI`, `PRES_AFF_IMP`, `FONTE_REDPRINC`, `SESSO_PPERC`, `TIPOLOGIA_FAM`, `FAM_ANZIANI`, `FAM_MINORI`,  `TIPO_DATO`, `TITOLO_STUDIO_PPERC`.
#
# To understand the meaning of this abbreviations we can look at the package called `codelist`. It can be queried by the previous discovered IDs. Let's for example explore `TIPOLOGIA_FAM`. Reading the XML above we see that the ID to query relative to the package `codelist` is: `CL_TIPOLOGIA_FAMILIARE1`. Querying the URL `http://sdmx.istat.it/SDMXWS/rest/codelist/IT1/CL_TIPOLOGIA_FAMILIARE1` in Postman (some API response are too long to be loaded in a Jupyter Notebook) we can see that this dimension is relative to the territory of Italy and all Italian Municipality are listed with full name and ID. An example of one record is shown below:
#
#
# `<structure:Code id="SLL_2011_116" urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_ITTER107(5.6).SLL_2011_116">`
# <br>
# `    <common:Name xml:lang="it">Fossano</common:Name>`
#     <br>
# `    <common:Name xml:lang="en">Fossano</common:Name>`
#     <br>
# `    <structure:Parent>`
#     <br>
# `        <Ref id="IT" />`
#         <br>
# `    </structure:Parent>`
#     <br>
# `</structure:Code>`
#
# Since we are interested in all kinds of family, we find that `99` is the ID we will need for our API request for this dimension:Code>

# %%
# 2 - Explore the meaning of the dimensions of the dataset

response = requests.get('http://sdmx.istat.it/SDMXWS/rest/codelist/IT1/CL_TIPOLOGIA_FAMILIARE1')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

print(json_string_data)
# Out:
# 200
# {
#       "message:Structure": {
#             "@xmlns:message": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message",
#             "@xmlns:structure": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/structure",
#             "@xmlns:common": "http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common",
#             "message:Header": {
#                   "message:ID": "IDREF40",
#                   "message:Test": "false",
#                   "message:Prepared": "2023-10-14T17:30:23.0695452+02:00",
#                   "message:Sender": {
#                         "@id": "Unknown"
#                   },
#                   "message:Receiver": {
#                         "@id": "Unknown"
#                   }
#             },
#             "message:Structures": {
#                   "structure:Codelists": {
#                         "structure:Codelist": {
#                               "@id": "CL_TIPOLOGIA_FAMILIARE1",
#                               "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Codelist=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2)",
#                               "@agencyID": "IT1",
#                               "@version": "1.2",
#                               "@isFinal": "true",
#                               "common:Name": [
#                                     {
#                                           "@xml:lang": "it",
#                                           "#text": "Tipologia familiare 1"
#                                     },
#                                     {
#                                           "@xml:lang": "en",
#                                           "#text": "Household typology 1"
#                                     }
#                               ],
#                               "structure:Code": [
#                                     {
#                                           "@id": "32",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).32",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "famiglie con almeno un nucleo"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "family household size"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "19",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).19",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "monogenitore con figli adulti"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single parent with adult sons"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "31",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).31",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "altro"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "other"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "2",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).2",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola con meno di 65 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single member under 65"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "3",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).3",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola con 35-64 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single member 35- 64"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "16",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).16",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con almeno un figlio minore"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with at least one children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "22",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).22",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "famiglia con due anziani"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "household with two elderly members"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "9",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).9",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia senza figli con p.r.con meno di 35 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple without children with r.p. under 35"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "23",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).23",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "altro"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "other typology"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "25",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).25",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola femmina"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "female lone person"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "21",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).21",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "famiglia con un anziano"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "household with one elderly member"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "8",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).8",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia senza figli con p.r. con 35-64 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple without children with r.p. 35-64"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "33",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).33",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "Tipologia familiare per previsioni sulle famiglie"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "Household type by households projections"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "17",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).17",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con figli adulti"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with adult sons"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "27",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).27",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona in coppia con figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "partner with children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "15",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).15",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "monogenitore"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single parent"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "11",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).11",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "4",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).4",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola con meno di 35 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single member under 35"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "10",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).10",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia senza figli con p.r. con 65 anni o pi\u00f9"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple without children with r.p. 65 and over"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "18",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).18",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "monogenitore con almeno un figlio minore"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single parent with at least one children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "99",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).99",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "totale"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "total"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "6",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).6",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia senza figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple without children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "28",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).28",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "genitore solo maschio"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "male lone parent"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "20",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).20",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "famiglia con almeno un anziano"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "household with at least one elderly member"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "1",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).1",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "26",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).26",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona in coppia senza figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "partner without children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "30",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).30",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "figlio/a"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "son/daughter"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "24",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).24",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola maschio"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "male lone person"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "13",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).13",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con 2 figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with 2 children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "29",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).29",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "genitore solo femmina"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "female lone parent"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "7",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).7",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia senza figli con p.r. con meno di 65 anni"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple without children with r.p. under 65"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "14",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).14",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con 3 e pi\u00f9 figli"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with 3 or more children"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "5",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).5",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "persona sola con 65 anni o pi\u00f9"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "single member 65 and over"
#                                                 }
#                                           ]
#                                     },
#                                     {
#                                           "@id": "12",
#                                           "@urn": "urn:sdmx:org.sdmx.infomodel.codelist.Code=IT1:CL_TIPOLOGIA_FAMILIARE1(1.2).12",
#                                           "common:Name": [
#                                                 {
#                                                       "@xml:lang": "it",
#                                                       "#text": "coppia con 1 figlio"
#                                                 },
#                                                 {
#                                                       "@xml:lang": "en",
#                                                       "#text": "couple with one child"
#                                                 }
#                                           ]
#                                     }
#                               ]
#                         }
#                   }
#             }
#       }
# }

# %% [markdown]
# We explore all the other dimensions and since for our purpose we need all the ages we will have to understand how the are divided and which are the values. In order to do that we need to know the ID of our datasets. We can checkit in the URL on IstatData, and we see that is `29_7`.
# We can query the API rest service like this to obtain our result:

# %%
# 3 -  EXPLORE VALUES IN DIMENSIONS
response = requests.get('http://sdmx.istat.it/SDMXWS/rest/availableconstraint/29_7')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Print is disable in documentation since the response is too long to be shown here. Uncomment to see it.
# print(json_string_data)
# Out:
# 200

# %% [markdown]
# We can now compose our final query for retrive all values relative of all ages, for all Italy, divided by sex.
# Our final URL will be: http://sdmx.istat.it/SDMXWS/rest/data/29_7/..IT.1+2./
#
# The filters we apply after the `data` request are: `IT`that is equal to whole Italian nation, and `1+2`where we specify we want the data divided by males (1) and females (2). When you see just the period `.` it means the filter is not specified, so in our case, we are requesting all ages (from `Y0` to `Y_GE100`) of all available time periods (from  2019 to 2022).

# %%
# 4 -  FINAL QUERY WITH FILTERS
response = requests.get('http://sdmx.istat.it/SDMXWS/rest/data/32_292/A.TOTAL.ITI+ITF.9.99.99.2.9.9.99.9.9..99')
print(response.status_code)

if response.status_code == 200:
    content = response.content
    
    if len(content) > 0:
        try:
            xml_data = xmltodict.parse(content)
            json_string_data = json.dumps(xml_data,
                                    allow_nan = True, # If we hadn't set allow_nan to
                                                      # true we would have got
                                                      # ValueError: Out of range float
                                                      # values are not JSON compliant
                                    indent = 6) # Indentation can be used for pretty-printing
            # Now you can work with the parsed JSON data
        except json.JSONDecodeError as e:
            print("Error decoding JSON:", e)
    else:
        print("Empty content received.")
else:
    print("Request failed with status code:", response.status_code)

# Print is disable in documentation since the response is too long to be shown here. Uncomment to see it.
# print(json_string_data)
# Out:
# 200

# %% [markdown]
# Now we crate a well formed JSON sting from the response.
#
# The code snippet performs the following tasks:
#
# 1. It takes a JSON string called `json_string_data` and creates a nested dictionary, `nested_dict`, using the `json.loads()` function. This step is essential to process and extract information from the JSON data.
#
# 2. It defines a translation dictionary, `sex_translation`, which maps numeric codes to corresponding gender labels ('1' to 'Male' and '2' to 'Female'). This dictionary will be used to translate the sex values later.
#
# 3. It initializes an empty list, `result`, which will store the extracted information from the nested dictionary.
#
# 4. It iterates over the series data in the nested dictionary. Each series represents a set of observations for a specific combination of variables.
#
# 5. Within each series, it retrieves the territory and sex values by searching for specific keys ('ITTER107' and 'SESSO') in the series key. If found, it assigns the corresponding values to the `territory` and `sex` variables, respectively. The sex value is translated using the `sex_translation` dictionary.
#
# 6. It retrieves the observation values (`obs_values`) for each series and iterates over them. Each observation contains information about the year, age, and quantity.
#
# 7. It creates an entry dictionary that contains the extracted information, including the territory, year, sex, age, and quantity.
#
# 8. The entry dictionary is appended to the `result` list.
#
# 9. Finally, the `result` list is converted to a JSON string, `immigrants_demographic`, using `json.dumps()`. The type of the `immigrants_demographic` variable is printed to verify that it is a string.
#
# In summary, sintethis code processes the nested dictionary, extracts specific information, translates values, and organizes the extracted data into a clean JSON format suitable for visualization or further analysis.

# %%
# Creating a nested dictonary from the response in order to create a clean JSON for our visualization
nested_dict = json.loads(json_string_data)

# Translation dictionary
sex_translation = {
    '1': 'Male',
    '2': 'Female'
}

# Extracting information
result = []

series_data = nested_dict['message:GenericData']['message:DataSet']['generic:Series']
for series in series_data:
    series_key = series['generic:SeriesKey']
    territory = None
    sex = None

    for value in series_key['generic:Value']:
        if value['@id'] == 'ITTER107':
            territory = value['@value']
        elif value['@id'] == 'SESSO':
            sex_value = value['@value']
            sex = sex_translation.get(sex_value)

    obs_values = series['generic:Obs']
    for obs in obs_values:
        year = obs['generic:ObsDimension']['@value']
        age = series_key['generic:Value'][1]['@value']
        quantity = obs['generic:ObsValue']['@value']

        entry = {
            'Territory': territory,
            'Year': int(year),
            'Sex': sex,
            'Age': age,
            'Quantity': int(quantity)
        }
        result.append(entry)

# Convert result to JSON
immigrants_demographic = json.dumps(result)
print(type(immigrants_demographic))
# Out:
# <class 'str'>

# %% [markdown]
# The next code snippet performs the following tasks:
#
# 1. It converts the `immigrants_demographic` string, which contains a JSON representation, into a JSON object using `json.loads()`. This step allows easier manipulation and access to the data.
#
# 2. It specifies the folder path where the resulting JSON file will be saved. In this case, the folder path is "../_datasets/Clean".
#
# 3. It creates the specified folder if it does not already exist using `os.makedirs()`. This ensures that the folder is available to store the JSON file.
#
# 4. It defines the filename for the JSON file as "immigrants_demographic.json".
#
# 5. It generates the complete file path by joining the folder path and filename using `os.path.join()`.
#
# 6. It saves the `immigrants_demographic_json` JSON object to a file specified by the file path. This is achieved using `json.dump()` with the file opened in write mode ("w").
#
# 7. The JSON data is formatted with an indent of 4 spaces to improve readability within the file.
#
# 8. Finally, it prints a message confirming the successful saving of the JSON data, along with the file path where it was saved.
#
# So basically this code snippet takes a JSON object, saves it as a JSON file in a specified directory, and provides feedback on the successful saving of the file.

# %%
# Convert immigrants_demographic string to JSON object
immigrants_demographic_json = json.loads(immigrants_demographic)

# Specify the folder path to save the JSON file
folder_path = "../_datasets/Clean"

# Create the folder if it doesn't exist
os.makedirs(folder_path, exist_ok=True)

# Define the filename for the JSON file
filename = "net_income.json"

# Generate the file path
file_path = os.path.join(folder_path, filename)

# Save the immigrants_demographic JSON object to file
with open(file_path, "w") as file:
    json.dump(immigrants_demographic_json, file, indent=4)

print(f"JSON data saved to: {file_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Convert immigrants_demographic string to JSON object
# ----> 2 immigrants_demographic_json = json.loads(immigrants_demographic)
#       4 # Specify the folder path to save the JSON file
#       5 folder_path = "../_datasets/Clean"
#
# NameError: name 'immigrants_demographic' is not defined

# %% [markdown]
# The last code snippet loads a JSON file, modifies the "Age" values by removing a "Y" prefix if present, and saves the modified data back to the same JSON file.

# %%
import json
import os

# Specify the path to the JSON file
file_path = "../_datasets/Clean/immigrants_demographic.json"

# Load the JSON file
with open(file_path, "r") as file:
    data = json.load(file)

# Iterate over the entries and modify the Age values
for entry in data:
    age = entry["Age"]
    if age.startswith("Y") and age[1:].isdigit():
        entry["Age"] = age[1:]

# Save the modified data back to the JSON file
with open(file_path, "w") as file:
    json.dump(data, file, indent=4)

print(f"JSON data saved to: {file_path}")
# Out:
# JSON data saved to: ../_datasets/Clean/immigrants_demographic.json
